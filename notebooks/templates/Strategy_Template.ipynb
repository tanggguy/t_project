# %% [markdown]
# # Strategy Notebook Template
#
# Use this notebook to document, visualise, and backtest a swing strategy (1D / intraday).

# %% [markdown]
# ## Sections
# - Hypothesis & market regime
# - Indicators & parameters
# - Entry / exit logic
# - Position sizing (default 2% risk)
# - Visual checks (price + signals)
# - Backtest metrics
# - Interactive review (entries/exits + equity)
# - Robustness checklist

# %% [markdown]
# ## 1. Hypothesis
# Describe the inefficiency the strategy targets (pattern, regime, instruments).

# %% [markdown]
# ## 2. Regime Filters
# List the filters you will use (trend, volatility, market breadth, etc.).

# %%
from pathlib import Path
import sys

def find_project_root(start=None):
    start = Path.cwd() if start is None else Path(start)
    for candidate in [start] + list(start.parents):
        if (candidate / 'utils').exists() and (candidate / 'backtesting').exists():
            return candidate
    return start

PROJECT_ROOT = find_project_root()
if str(PROJECT_ROOT) not in sys.path:
    sys.path.append(str(PROJECT_ROOT))

print('Project root:', PROJECT_ROOT)
# Out:
# Project root: c:\Users\saill\Desktop\t_project

# %%
# Notebook configuration (edit per strategy)
TICKER = 'SPY'
START_DATE = '2015-01-01'
END_DATE = '2025-01-01'

TIMEFRAME_DAILY = '1d'
TIMEFRAME_INTRADAY = '1h'
RESAMPLE_TO = '4H'

RISK_PCT = 0.02
DEFAULT_STOP_DISTANCE = 0.03

# %%
import pandas as pd

from utils.data_manager import DataManager
from utils.data_processor import resample_data

dm = DataManager()
df_daily = dm.get_data(TICKER, START_DATE, END_DATE, interval=TIMEFRAME_DAILY)
df_intraday = dm.get_data(TICKER, START_DATE, END_DATE, interval=TIMEFRAME_INTRADAY)

if df_intraday is not None and not df_intraday.empty:
    df_4h = resample_data(df_intraday, rule=RESAMPLE_TO)
else:
    df_4h = pd.DataFrame()
    print('Intraday data unavailable; continuing without 4H resample.')

print(f'Daily bars: {len(df_daily)}')
if not df_4h.empty:
    print(f'4H bars: {len(df_4h)}')
# Out:
# 2025-11-03 01:49:55 - utils.data_manager - INFO - DataManager initialisé. Cache: C:\Users\saill\Desktop\t_project\data\cache. Timezone: Europe/Paris
# 2025-11-03 01:49:55 - utils.data_manager - INFO - Cache insuffisant pour SPY (demandé: 2015-01-01 à 2025-01-01). Re-téléchargement.
# 2025-11-03 01:49:55 - utils.data_manager - INFO - Téléchargement pour SPY (plage par défaut : 2015-01-01 à 2025-10-31)...
# 2025-11-03 01:49:55 - utils.data_manager - INFO - Téléchargement de SPY (2015-01-01 à 2025-10-31, 1d)...
# 2025-11-03 01:49:56 - utils.data_manager - INFO - Données téléchargées avec succès pour SPY (2724 lignes).
# 2025-11-03 01:49:56 - utils.data_manager - INFO - [OK] Données prêtes pour SPY (2516 lignes de 2015-01-01 à 2025-01-01).
# 2025-11-03 01:49:56 - utils.data_manager - INFO - Téléchargement pour SPY (plage par défaut : 2015-01-01 à 2025-10-31)...
# 2025-11-03 01:49:56 - utils.data_manager - INFO - Téléchargement de SPY (2015-01-01 à 2025-10-31, 1h)...
# 2025-11-03 01:49:56 - utils.data_manager - INFO - Plage intraday trop longue pour Yahoo (2015-01-01 -> 2025-10-31). Clamp start -> 2023-11-02.
# $SPY: possibly delisted; no price data found  (1h 2023-11-02 -> 2025-10-31) (Yahoo error = "1h data not available for startTime=1698897600 and endTime=1761883200. The requested range must be within the last 730 days.")
# 2025-11-03 01:49:56 - utils.data_manager - WARNING - Aucune donnée retournée par yfinance pour SPY.
# 2025-11-03 01:49:56 - utils.data_manager - ERROR - Impossible d'obtenir des données pour SPY.
# Intraday data unavailable; continuing without 4H resample.
# Daily bars: 2516

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots

df_plot = df_daily.copy()
try:
    import pandas_ta as ta
    df_plot['EMA_FAST'] = ta.ema(df_plot['close'], length=20)
    df_plot['EMA_SLOW'] = ta.ema(df_plot['close'], length=50)
    df_plot['RSI14'] = ta.rsi(df_plot['close'], length=14)
except Exception:
    df_plot['EMA_FAST'] = df_plot['close'].rolling(20).mean()
    df_plot['EMA_SLOW'] = df_plot['close'].rolling(50).mean()
    df_plot['RSI14'] = df_plot['close'].rolling(14).apply(lambda _ : 50.0)

if getattr(df_plot.index, 'tz', None) is not None:
    xs = df_plot.index.tz_convert('UTC').tz_localize(None)
else:
    xs = df_plot.index

fig = make_subplots(rows=2, cols=1, shared_xaxes=True, vertical_spacing=0.05, row_heights=[0.7, 0.3])
fig.add_trace(go.Candlestick(x=xs, open=df_plot['open'], high=df_plot['high'], low=df_plot['low'], close=df_plot['close'], name='OHLC'), row=1, col=1)
fig.add_trace(go.Scatter(x=xs, y=df_plot['EMA_FAST'], mode='lines', name='EMA_FAST'), row=1, col=1)
fig.add_trace(go.Scatter(x=xs, y=df_plot['EMA_SLOW'], mode='lines', name='EMA_SLOW'), row=1, col=1)
fig.add_trace(go.Scatter(x=xs, y=df_plot['RSI14'], mode='lines', name='RSI14', line=dict(color='purple')), row=2, col=1)
fig.update_yaxes(title_text='Price', row=1, col=1)
fig.update_yaxes(title_text='RSI', row=2, col=1, range=[0, 100])
fig.update_layout(title=f'{TICKER} quick visual check', xaxis_rangeslider_visible=False, template='plotly_white')
fig.show()

# %% [markdown]
# ## 3. Entry / Exit Logic
# Document the exact boolean rules for entries, exits, and invalidation.

# %%
import importlib
import backtrader as bt

from backtesting.engine import BacktestEngine
from risk_management.position_sizing import FixedFractionalSizer
from utils.config_loader import get_settings

STRATEGY_PATH = 'strategies.implementations.simple_ma_managed_strategy.SimpleMaManagedStrategy'  # update
STRATEGY_PARAMS = {}  # override defaults here

module_name, class_name = STRATEGY_PATH.rsplit('.', 1)
StrategyClass = getattr(importlib.import_module(module_name), class_name)

engine = BacktestEngine()
engine.cerebro.addanalyzer(bt.analyzers.TimeReturn, _name='timereturn')
engine.add_sizer(FixedFractionalSizer, risk_pct=RISK_PCT, stop_distance=DEFAULT_STOP_DISTANCE)
engine.add_data(df_daily, name='data_1d')
if not df_4h.empty:
    engine.add_data(df_4h, name='data_4h')

engine.add_strategy(StrategyClass, **STRATEGY_PARAMS)
results = engine.run()
strategy_instance = results[0]
# Out:
# 2025-11-03 01:50:07 - backtesting.engine - INFO - Initialisation du BacktestEngine...
# 2025-11-03 01:50:07 - backtesting.engine - INFO - Capital initial du broker fixé à : 10,000.00
# 2025-11-03 01:50:07 - backtesting.engine - INFO - Commission (pourcentage) fixée à : 0.1000%
# 2025-11-03 01:50:07 - backtesting.engine - INFO - Slippage (pourcentage) fixé à : 0.0500%
# 2025-11-03 01:50:07 - backtesting.engine - INFO - Position Sizer 'FixedFractionalSizer' ajouté. Paramètres: (risk_pct=0.02, stop_distance=0.03)
# 2025-11-03 01:50:07 - backtesting.engine - INFO - Flux de données 'data_1d' ajouté. Période: 2015-01-02 à 2024-12-31.
# 2025-11-03 01:50:07 - backtesting.engine - INFO - Stratégie 'SimpleMaManagedStrategy' ajoutée. Paramètres: ()
# 2025-11-03 01:50:07 - backtesting.engine - INFO - --- DÉMARRAGE DU BACKTEST ---
# 2025-11-03 01:50:10 - strategies.implementations.simple_ma_managed_strategy - INFO - SimpleMaManagedStrategy initialisée - Fast MA: 10, Slow MA: 30
# 2025-11-03 01:50:10 - strategies.implementations.simple_ma_managed_strategy - INFO - Signal ACHAT - Golden Cross prix 174.92 (Fast: 173.84, Slow: 173.72)
# 2025-11-03 01:50:10 - risk_management.position_sizing - INFO - FixedFractionalSizer: size=38, risk_amount=200.00, risk_per_share=5.25, portfolio_value=10000.00
# 2025-11-03 01:50:10 - risk_management.stop_loss - INFO - Stop loss déclenché ! Prix=171.47, Stop=171.75, Type=long
# 2025-11-03 01:50:10 - strategies.implementations.simple_ma_managed_strategy - INFO - Signal ACHAT - Golden Cross prix 170.13 (Fast: 165.04, Slow: 164.93)
# 2025-11-03 01:50:10 - risk_management.position_sizing - INFO - FixedFractionalSizer: size=38, risk_amount=195.70, risk_per_share=5.10, portfolio_value=9785.23
# 2025-11-03 01:50:10 - risk_management.take_profit - INFO - Take Profit déclenché ! Prix=177.78, Target=177.10, Type=long
# 2025-11-03 01:50:10 - strategies.implementations.simple_ma_managed_strategy - INFO - Signal ACHAT - Golden Cross prix 164.23 (Fast: 161.66, Slow: 161.20)
# 2025-11-03 01:50:10 - risk_management.position_sizing - INFO - FixedFractionalSizer: size=40, risk_amount=200.80, risk_per_share=4.93, portfolio_value=10039.96
# 2025-11-03 01:50:10 - risk_management.take_profit - INFO - Take Profit déclenché ! Prix=173.94, Target=172.87, Type=long
# 2025-11-03 01:50:10 - strategies.implementations.simple_ma_managed_strategy - INFO - Signal ACHAT - Golden Cross prix 179.66 (Fast: 177.43, Slow: 177.12)
# 2025-11-03 01:50:10 - risk_management.position_sizing - INFO - FixedFractionalSizer: size=38, risk_amount=208.21, risk_per_share=5.39, portfolio_value=10410.39
# 2025-11-03 01:50:10 - risk_management.stop_loss - INFO - Stop loss déclenché ! Prix=174.56, Stop=176.60, Type=long
# 2025-11-03 01:50:10 - strategies.implementations.simple_ma_managed_strategy - INFO - Signal ACHAT - Golden Cross prix 184.61 (Fast: 180.18, Slow: 179.21)
# 2025-11-03 01:50:10 - risk_management.position_sizing - INFO - FixedFractionalSizer: size=36, risk_amount=203.16, risk_per_share=5.54, portfolio_value=10157.78
# 2025-11-03 01:50:10 - risk_management.stop_loss - INFO - Stop loss déclenché ! Prix=180.22, Stop=180.90, Type=long
# 2025-11-03 01:50:10 - strategies.implementations.simple_ma_managed_strategy - INFO - Signal ACHAT - Golden Cross prix 188.42 (Fast: 184.63, Slow: 184.59)
# 2025-11-03 01:50:10 - risk_management.position_sizing - INFO - FixedFractionalSizer: size=35, risk_amount=199.44, risk_per_share=5.65, portfolio_value=9971.80
# 2025-11-03 01:50:10 - risk_management.take_profit - INFO - Take Profit déclenché ! Prix=196.60, Target=195.59, Type=long
# 2025-11-03 01:50:10 - strategies.implementations.simple_ma_managed_strategy - INFO - Signal ACHAT - Golden Cross prix 208.08 (Fast: 205.55, Slow: 205.27)
# 2025-11-03 01:50:10 - risk_management.position_sizing - INFO - FixedFractionalSizer: size=32, risk_amount=204.98, risk_per_share=6.24, portfolio_value=10249.22
# 2025-11-03 01:50:10 - risk_management.take_profit - INFO - Take Profit déclenché ! Prix=216.44, Target=215.93, Type=long
# 2025-11-03 01:50:10 - strategies.implementations.simple_ma_managed_strategy - INFO - Signal ACHAT - Golden Cross prix 216.08 (Fast: 215.73, Slow: 215.50)
# 2025-11-03 01:50:10 - risk_management.position_sizing - INFO - FixedFractionalSizer: size=32, risk_amount=209.98, risk_per_share=6.48, portfolio_value=10498.83
# 2025-11-03 01:50:10 - risk_management.take_profit - INFO - Take Profit déclenché ! Prix=227.61, Target=227.12, Type=long
# 2025-11-03 01:50:10 - strategies.implementations.simple_ma_managed_strategy - INFO - Signal ACHAT - Golden Cross prix 242.63 (Fast: 241.43, Slow: 241.40)
# 2025-11-03 01:50:10 - risk_management.position_sizing - INFO - FixedFractionalSizer: size=29, risk_amount=216.05, risk_per_share=7.28, portfolio_value=10802.53
# 2025-11-03 01:50:10 - risk_management.stop_loss - INFO - Stop loss déclenché ! Prix=240.39, Stop=241.91, Type=long
# 2025-11-03 01:50:10 - strategies.implementations.simple_ma_managed_strategy - INFO - Signal ACHAT - Golden Cross prix 236.91 (Fast: 237.29, Slow: 236.87)
# 2025-11-03 01:50:10 - risk_management.position_sizing - INFO - FixedFractionalSizer: size=30, risk_amount=213.74, risk_per_share=7.11, portfolio_value=10687.10
# 2025-11-03 01:50:10 - risk_management.take_profit - INFO - Take Profit déclenché ! Prix=243.15, Target=243.06, Type=long
# 2025-11-03 01:50:10 - strategies.implementations.simple_ma_managed_strategy - INFO - Signal ACHAT - Golden Cross prix 249.59 (Fast: 245.96, Slow: 245.51)
# 2025-11-03 01:50:10 - risk_management.position_sizing - INFO - FixedFractionalSizer: size=28, risk_amount=216.93, risk_per_share=7.49, portfolio_value=10846.71
# 2025-11-03 01:50:10 - risk_management.take_profit - INFO - Take Profit déclenché ! Prix=260.21, Target=259.35, Type=long
# 2025-11-03 01:50:10 - strategies.implementations.simple_ma_managed_strategy - INFO - Signal ACHAT - Golden Cross prix 245.47 (Fast: 246.55, Slow: 246.19)
# 2025-11-03 01:50:10 - risk_management.position_sizing - INFO - FixedFractionalSizer: size=30, risk_amount=222.16, risk_per_share=7.36, portfolio_value=11107.78
# 2025-11-03 01:50:10 - risk_management.stop_loss - INFO - Stop loss déclenché ! Prix=236.07, Stop=236.49, Type=long
# 2025-11-03 01:50:10 - strategies.implementations.simple_ma_managed_strategy - INFO - Signal ACHAT - Golden Cross prix 235.40 (Fast: 231.12, Slow: 230.64)
# 2025-11-03 01:50:10 - risk_management.position_sizing - INFO - FixedFractionalSizer: size=30, risk_amount=217.81, risk_per_share=7.06, portfolio_value=10890.45
# 2025-11-03 01:50:10 - risk_management.take_profit - INFO - Take Profit déclenché ! Prix=247.24, Target=246.68, Type=long
# 2025-11-03 01:50:11 - strategies.implementations.simple_ma_managed_strategy - INFO - Signal ACHAT - Golden Cross prix 262.06 (Fast: 258.71, Slow: 258.18)
# 2025-11-03 01:50:11 - risk_management.position_sizing - INFO - FixedFractionalSizer: size=28, risk_amount=225.50, risk_per_share=7.86, portfolio_value=11275.17
# 2025-11-03 01:50:11 - risk_management.take_profit - INFO - Take Profit déclenché ! Prix=273.70, Target=272.65, Type=long
# 2025-11-03 01:50:11 - strategies.implementations.simple_ma_managed_strategy - INFO - Signal ACHAT - Golden Cross prix 271.47 (Fast: 266.52, Slow: 265.51)
# 2025-11-03 01:50:11 - risk_management.position_sizing - INFO - FixedFractionalSizer: size=28, risk_amount=231.69, risk_per_share=8.14, portfolio_value=11584.31
# 2025-11-03 01:50:11 - risk_management.stop_loss - INFO - Stop loss déclenché ! Prix=263.45, Stop=265.98, Type=long
# 2025-11-03 01:50:11 - strategies.implementations.simple_ma_managed_strategy - INFO - Signal ACHAT - Golden Cross prix 273.47 (Fast: 271.65, Slow: 271.12)
# 2025-11-03 01:50:11 - risk_management.position_sizing - INFO - FixedFractionalSizer: size=27, risk_amount=227.05, risk_per_share=8.20, portfolio_value=11352.33
# 2025-11-03 01:50:11 - risk_management.take_profit - INFO - Take Profit déclenché ! Prix=285.37, Target=285.23, Type=long
# 2025-11-03 01:50:11 - strategies.implementations.simple_ma_managed_strategy - INFO - Signal ACHAT - Golden Cross prix 262.36 (Fast: 244.58, Slow: 242.94)
# 2025-11-03 01:50:11 - risk_management.position_sizing - INFO - FixedFractionalSizer: size=29, risk_amount=233.48, risk_per_share=7.87, portfolio_value=11674.15
# 2025-11-03 01:50:11 - risk_management.take_profit - INFO - Take Profit déclenché ! Prix=271.07, Target=267.05, Type=long
# 2025-11-03 01:50:11 - strategies.implementations.simple_ma_managed_strategy - INFO - Signal ACHAT - Golden Cross prix 323.35 (Fast: 314.96, Slow: 314.31)
# 2025-11-03 01:50:11 - risk_management.position_sizing - INFO - FixedFractionalSizer: size=24, risk_amount=240.61, risk_per_share=9.70, portfolio_value=12030.35
# 2025-11-03 01:50:11 - risk_management.stop_loss - INFO - Stop loss déclenché ! Prix=318.84, Stop=321.99, Type=long
# 2025-11-03 01:50:11 - strategies.implementations.simple_ma_managed_strategy - INFO - Signal ACHAT - Golden Cross prix 332.51 (Fast: 319.95, Slow: 319.36)
# 2025-11-03 01:50:11 - risk_management.position_sizing - INFO - FixedFractionalSizer: size=23, risk_amount=237.40, risk_per_share=9.98, portfolio_value=11869.94
# 2025-11-03 01:50:11 - risk_management.take_profit - INFO - Take Profit déclenché ! Prix=344.80, Target=342.46, Type=long
# 2025-11-03 01:50:11 - strategies.implementations.simple_ma_managed_strategy - INFO - Signal ACHAT - Golden Cross prix 371.93 (Fast: 364.75, Slow: 363.82)
# 2025-11-03 01:50:11 - risk_management.position_sizing - INFO - FixedFractionalSizer: size=21, risk_amount=242.70, risk_per_share=11.16, portfolio_value=12134.82
# 2025-11-03 01:50:11 - risk_management.take_profit - INFO - Take Profit déclenché ! Prix=381.69, Target=381.18, Type=long
# 2025-11-03 01:50:11 - strategies.implementations.simple_ma_managed_strategy - INFO - Signal ACHAT - Golden Cross prix 393.84 (Fast: 390.83, Slow: 390.72)
# 2025-11-03 01:50:11 - risk_management.position_sizing - INFO - FixedFractionalSizer: size=20, risk_amount=247.18, risk_per_share=11.82, portfolio_value=12359.08
# 2025-11-03 01:50:11 - risk_management.take_profit - INFO - Take Profit déclenché ! Prix=410.42, Target=410.33, Type=long
# 2025-11-03 01:50:11 - strategies.implementations.simple_ma_managed_strategy - INFO - Signal ACHAT - Golden Cross prix 426.03 (Fast: 416.08, Slow: 415.73)
# 2025-11-03 01:50:11 - risk_management.position_sizing - INFO - FixedFractionalSizer: size=19, risk_amount=252.67, risk_per_share=12.78, portfolio_value=12633.32
# 2025-11-03 01:50:11 - risk_management.take_profit - INFO - Take Profit déclenché ! Prix=445.03, Target=444.81, Type=long
# 2025-11-03 01:50:11 - strategies.implementations.simple_ma_managed_strategy - INFO - Signal ACHAT - Golden Cross prix 440.98 (Fast: 439.99, Slow: 439.80)
# 2025-11-03 01:50:11 - risk_management.position_sizing - INFO - FixedFractionalSizer: size=19, risk_amount=259.02, risk_per_share=13.23, portfolio_value=12950.86
# 2025-11-03 01:50:11 - risk_management.stop_loss - INFO - Stop loss déclenché ! Prix=423.84, Stop=427.56, Type=long
# 2025-11-03 01:50:11 - strategies.implementations.simple_ma_managed_strategy - INFO - Signal ACHAT - Golden Cross prix 422.35 (Fast: 413.00, Slow: 412.90)
# 2025-11-03 01:50:11 - risk_management.position_sizing - INFO - FixedFractionalSizer: size=19, risk_amount=252.76, risk_per_share=12.67, portfolio_value=12638.10
# 2025-11-03 01:50:11 - risk_management.stop_loss - INFO - Stop loss déclenché ! Prix=418.66, Stop=420.14, Type=long
# 2025-11-03 01:50:11 - strategies.implementations.simple_ma_managed_strategy - INFO - Signal ACHAT - Golden Cross prix 395.64 (Fast: 389.21, Slow: 387.28)
# 2025-11-03 01:50:11 - risk_management.position_sizing - INFO - FixedFractionalSizer: size=21, risk_amount=251.25, risk_per_share=11.87, portfolio_value=12562.28
# 2025-11-03 01:50:11 - risk_management.stop_loss - INFO - Stop loss déclenché ! Prix=382.04, Stop=383.52, Type=long
# 2025-11-03 01:50:11 - strategies.implementations.simple_ma_managed_strategy - INFO - Signal ACHAT - Golden Cross prix 374.92 (Fast: 367.21, Slow: 367.18)
# 2025-11-03 01:50:11 - risk_management.position_sizing - INFO - FixedFractionalSizer: size=21, risk_amount=243.15, risk_per_share=11.25, portfolio_value=12157.32
# 2025-11-03 01:50:11 - risk_management.take_profit - INFO - Take Profit déclenché ! Prix=393.77, Target=392.40, Type=long
# 2025-11-03 01:50:11 - strategies.implementations.simple_ma_managed_strategy - INFO - Signal ACHAT - Golden Cross prix 366.62 (Fast: 356.58, Slow: 356.11)
# 2025-11-03 01:50:11 - risk_management.position_sizing - INFO - FixedFractionalSizer: size=22, risk_amount=249.36, risk_per_share=11.00, portfolio_value=12467.97
# 2025-11-03 01:50:11 - risk_management.stop_loss - INFO - Stop loss déclenché ! Prix=356.06, Stop=357.37, Type=long
# 2025-11-03 01:50:11 - strategies.implementations.simple_ma_managed_strategy - INFO - Signal ACHAT - Golden Cross prix 383.49 (Fast: 375.93, Slow: 375.09)
# 2025-11-03 01:50:11 - risk_management.position_sizing - INFO - FixedFractionalSizer: size=21, risk_amount=246.31, risk_per_share=11.50, portfolio_value=12315.74
# 2025-11-03 01:50:11 - risk_management.take_profit - INFO - Take Profit déclenché ! Prix=396.05, Target=392.54, Type=long
# 2025-11-03 01:50:11 - strategies.implementations.simple_ma_managed_strategy - INFO - Signal ACHAT - Golden Cross prix 390.69 (Fast: 383.32, Slow: 383.02)
# 2025-11-03 01:50:11 - risk_management.position_sizing - INFO - FixedFractionalSizer: size=21, risk_amount=252.24, risk_per_share=11.72, portfolio_value=12611.93
# 2025-11-03 01:50:11 - risk_management.take_profit - INFO - Take Profit déclenché ! Prix=414.13, Target=412.05, Type=long
# 2025-11-03 01:50:11 - strategies.implementations.simple_ma_managed_strategy - INFO - Signal ACHAT - Golden Cross prix 432.77 (Fast: 434.23, Slow: 433.39)
# 2025-11-03 01:50:11 - risk_management.position_sizing - INFO - FixedFractionalSizer: size=20, risk_amount=261.33, risk_per_share=12.98, portfolio_value=13066.58
# 2025-11-03 01:50:11 - risk_management.stop_loss - INFO - Stop loss déclenché ! Prix=420.52, Stop=426.90, Type=long
# 2025-11-03 01:50:11 - strategies.implementations.simple_ma_managed_strategy - INFO - Signal ACHAT - Golden Cross prix 422.91 (Fast: 416.86, Slow: 416.69)
# 2025-11-03 01:50:11 - risk_management.position_sizing - INFO - FixedFractionalSizer: size=20, risk_amount=255.27, risk_per_share=12.69, portfolio_value=12763.74
# 2025-11-03 01:50:11 - risk_management.take_profit - INFO - Take Profit déclenché ! Prix=447.53, Target=446.69, Type=long
# 2025-11-03 01:50:11 - strategies.implementations.simple_ma_managed_strategy - INFO - Signal ACHAT - Golden Cross prix 510.70 (Fast: 501.51, Slow: 501.42)
# 2025-11-03 01:50:11 - risk_management.position_sizing - INFO - FixedFractionalSizer: size=17, risk_amount=262.40, risk_per_share=15.32, portfolio_value=13120.18
# 2025-11-03 01:50:11 - risk_management.take_profit - INFO - Take Profit déclenché ! Prix=532.58, Target=531.82, Type=long
# 2025-11-03 01:50:11 - strategies.implementations.simple_ma_managed_strategy - INFO - Signal ACHAT - Golden Cross prix 552.19 (Fast: 538.68, Slow: 537.62)
# 2025-11-03 01:50:11 - risk_management.position_sizing - INFO - FixedFractionalSizer: size=16, risk_amount=268.24, risk_per_share=16.57, portfolio_value=13411.86
# 2025-11-03 01:50:11 - risk_management.stop_loss - INFO - Stop loss déclenché ! Prix=532.24, Stop=536.90, Type=long
# 2025-11-03 01:50:11 - backtesting.engine - INFO - --- BACKTEST TERMINÉ ---

# %%
initial_capital = get_settings().get('backtest', {}).get('initial_capital', 10000.0)
try:
    from scripts.run_backtest import print_results
    print_results(results, initial_capital, df_daily)
except Exception as exc:
    final_value = strategy_instance.broker.getvalue()
    print(f'Final portfolio value: {final_value:,.2f}')
    print(f'(Detailed metrics unavailable: {exc})')
# Out:
# ======================================================================
# RÉSULTATS DU BACKTEST
# ======================================================================
#
# 📊 Période: 2015-01-02 à 2024-12-31
# 📊 Nombre de bougies: 2516
#
# 💰 PERFORMANCE
#    Capital Initial:              10,000.00 €
#    Capital Final:                13,103.44 €
#    P&L:                           3,103.44 € (+31.03%)
#    Retour Total:                     27.03%
#    Retour Moyen (annuel):             0.01%
#
# 📈 TRADES
#    Nombre Total:                        33
#    Trades Gagnants:                     20
#    Trades Perdants:                     13
#    Win Rate:                        60.61%
#    Gain Moyen:                      301.95 €
#    Perte Moyenne:                  -225.81 €
#
# 📉 RISQUE
#    Sharpe Ratio:           0.4295479387595011
#    Max Drawdown:                     8.59%
#
# ======================================================================

# %%
import pandas as pd

def _to_naive_timestamp(value):
    if value is None:
        return None
    ts = pd.Timestamp(value)
    if ts.tzinfo is not None:
        ts = ts.tz_convert('UTC').tz_localize(None)
    return ts

def extract_closed_trades(trade_analysis):
    closed = trade_analysis.get('closed', []) or []
    rows = []
    for trade in closed:
        entry_ts = _to_naive_timestamp(trade.get('open_datetime') or trade.get('dtopen'))
        exit_ts = _to_naive_timestamp(trade.get('close_datetime') or trade.get('dtclose'))
        rows.append({
            'entry_time': entry_ts,
            'exit_time': exit_ts,
            'entry_price': trade.get('open_price') or trade.get('price'),
            'exit_price': trade.get('close_price'),
            'size': trade.get('size', trade.get('opened')),
            'pnl': trade.get('pnl'),
        })
    return pd.DataFrame(rows)

trade_analysis = strategy_instance.analyzers.trades.get_analysis()
trades_df = extract_closed_trades(trade_analysis)

time_returns = strategy_instance.analyzers.timereturn.get_analysis()
if time_returns:
    equity_series = pd.Series(time_returns).sort_index()
    equity_curve = initial_capital * (1 + equity_series).cumprod()
else:
    equity_curve = pd.Series(dtype='float64')

if getattr(df_daily.index, 'tz', None) is not None:
    price_index = df_daily.index.tz_convert('UTC').tz_localize(None)
else:
    price_index = df_daily.index

price_lookup = df_daily[['close']].copy()
price_lookup.index = price_index

fig_bt = make_subplots(rows=2, cols=1, shared_xaxes=True, vertical_spacing=0.05, row_heights=[0.7, 0.3])
fig_bt.add_trace(go.Candlestick(x=price_index, open=df_daily['open'], high=df_daily['high'], low=df_daily['low'], close=df_daily['close'], name='OHLC'), row=1, col=1)
fig_bt.add_trace(go.Scatter(x=price_index, y=df_plot['EMA_FAST'], mode='lines', name='EMA_FAST'), row=1, col=1)
fig_bt.add_trace(go.Scatter(x=price_index, y=df_plot['EMA_SLOW'], mode='lines', name='EMA_SLOW'), row=1, col=1)

if not trades_df.empty:
    entries = trades_df.dropna(subset=['entry_time'])
    entry_prices = entries['entry_price']
    if entry_prices.isna().any():
        fallback = price_lookup['close'].reindex(entries['entry_time'], method='nearest')
        entry_prices = entry_prices.fillna(fallback)
    fig_bt.add_trace(go.Scatter(x=entries['entry_time'], y=entry_prices, mode='markers', name='Entry', marker=dict(symbol='triangle-up', color='green', size=10)), row=1, col=1)
    exits = trades_df.dropna(subset=['exit_time'])
    if not exits.empty:
        exit_prices = exits['exit_price']
        if exit_prices.isna().any():
            fallback_exit = price_lookup['close'].reindex(exits['exit_time'], method='nearest')
            exit_prices = exit_prices.fillna(fallback_exit)
        fig_bt.add_trace(go.Scatter(x=exits['exit_time'], y=exit_prices, mode='markers', name='Exit', marker=dict(symbol='triangle-down', color='red', size=10)), row=1, col=1)

if not equity_curve.empty:
    eq_index = equity_curve.index
    if getattr(eq_index, 'tz', None) is not None:
        eq_index = eq_index.tz_convert('UTC').tz_localize(None)
    fig_bt.add_trace(go.Scatter(x=eq_index, y=equity_curve, mode='lines', name='Equity Curve'), row=2, col=1)
else:
    fig_bt.add_trace(go.Scatter(x=[price_index.min()], y=[initial_capital], mode='lines', name='Equity Curve'), row=2, col=1)

fig_bt.update_yaxes(title_text='Price', row=1, col=1)
fig_bt.update_yaxes(title_text='Equity', row=2, col=1)
fig_bt.update_layout(title='Interactive backtest review', template='plotly_white', xaxis_rangeslider_visible=False)
fig_bt.show()

trades_df.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ## 4. Robustness Notes
# - Walk-forward / out-of-sample checks
# - Parameter sensitivity maps
# - Monte Carlo trade sequencing
# - Cost / slippage stress tests
